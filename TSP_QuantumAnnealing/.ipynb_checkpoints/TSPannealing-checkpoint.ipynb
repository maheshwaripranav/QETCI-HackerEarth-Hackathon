# %% [markdown]
# # Install packages

# %%
# !pip install dwave-system

# %%
# !pip install pandas -q

# %%
# !pip install boto3

# %%
pip install amazon-braket-sdk

# %%
pip install dwave-ocean-sdk

# %%
pip install amazon-braket-ocean-plugin

# %% [markdown]
# # Code begins here
# Source code obatained from [here](https://github.com/dwavesystems/dwave-networkx/blob/main/dwave_networkx/algorithms/tsp.py#L1).
#
# Other references: [Ref1](https://github.com/dwave-training/traveling-salesman/blob/master/hss_exercise.py), [Ref2](https://github.com/aws/amazon-braket-examples/blob/main/examples/quantum_annealing/Dwave_TravelingSalesmanProblem/Dwave_TravelingSalesmanProblem.ipynb).

# %%
import itertools
import numpy as np
from collections import defaultdict
from dwave_networkx.utils import binary_quadratic_model_sampler
import time

__all__ = ["traveling_salesperson",
           "traveling_salesperson_qubo",
           "traveling_salesman",
           "traveling_salesman_qubo",
           "is_hamiltonian_path",
           ]

@binary_quadratic_model_sampler(1)
def traveling_salesperson(G, sampler=None, lagrange=None, weight='weight',
                          start=None, **sampler_args):
    """Returns an approximate minimum traveling salesperson route.
    Defines a QUBO with ground states corresponding to the
    minimum routes and uses the sampler to sample
    from it.
    A route is a cycle in the graph that reaches each node exactly once.
    A minimum route is a route with the smallest total edge weight.
    Parameters
    ----------
    G : NetworkX graph
        The graph on which to find a minimum traveling salesperson route.
        This should be a complete graph with non-zero weights on every edge.
    sampler :
        A binary quadratic model sampler. A sampler is a process that
        samples from low energy states in models defined by an Ising
        equation or a Quadratic Unconstrained Binary Optimization
        Problem (QUBO). A sampler is expected to have a 'sample_qubo'
        and 'sample_ising' method. A sampler is expected to return an
        iterable of samples, in order of increasing energy. If no
        sampler is provided, one must be provided using the
        `set_default_sampler` function.
    lagrange : number, optional (default None)
        Lagrange parameter to weight constraints (visit every city once)
        versus objective (shortest distance route).
    weight : optional (default 'weight')
        The name of the edge attribute containing the weight.
    start : node, optional
        If provided, the route will begin at `start`.
    sampler_args :
        Additional keyword parameters are passed to the sampler.
    Returns
    -------
    route : list
       List of nodes in order to be visited on a route
    Examples
    --------
    >>> import dimod
    ...
    >>> G = nx.Graph()
    >>> G.add_weighted_edges_from({(0, 1, .1), (0, 2, .5), (0, 3, .1), (1, 2, .1),
    ...                            (1, 3, .5), (2, 3, .1)})
    >>> dnx.traveling_salesperson(G, dimod.ExactSolver(), start=0) # doctest: +SKIP
    [0, 1, 2, 3]
    Notes
    -----
    Samplers by their nature may not return the optimal solution. This
    function does not attempt to confirm the quality of the returned
    sample.
    """
    # Get a QUBO representation of the problem
    Q = traveling_salesperson_qubo(G, lagrange, weight)

    # use the sampler to find low energy states
    response = sampler.sample_qubo(Q, **sampler_args)

    sample = response.first.sample

    route = [None]*len(G)
    for (city, time), val in sample.items():
        if val:
            route[time] = city

    if start is not None and route[0] != start:
        # rotate to put the start in front
        idx = route.index(start)
        route = route[idx:] + route[:idx]

    return route

traveling_salesman = traveling_salesperson

def traveling_salesperson_qubo(G, lagrange=None, weight='weight', missing_edge_weight=None):
    """Return the QUBO with ground states corresponding to a minimum TSP route.
    If :math:`|G|` is the number of nodes in the graph, the resulting qubo will have:
    * :math:`|G|^2` variables/nodes
    * :math:`2 |G|^2 (|G| - 1)` interactions/edges
    Parameters
    ----------
    G : NetworkX graph
        A complete graph in which each edge has a attribute giving its weight.
    lagrange : number, optional (default None)
        Lagrange parameter to weight constraints (no edges within set)
        versus objective (largest set possible).
    weight : optional (default 'weight')
        The name of the edge attribute containing the weight.
    
    missing_edge_weight : number, optional (default None)
        For bi-directional graphs, the weight given to missing edges.
        If None is given (the default), missing edges will be set to
        the sum of all weights.
    Returns
    -------
    QUBO : dict
       The QUBO with ground states corresponding to a minimum travelling
       salesperson route. The QUBO variables are labelled `(c, t)` where `c`
       is a node in `G` and `t` is the time index. For instance, if `('a', 0)`
       is 1 in the ground state, that means the node 'a' is visted first.
    """
    N = G.number_of_nodes()

    if lagrange is None:
        # If no lagrange parameter provided, set to 'average' tour length.
        # Usually a good estimate for a lagrange parameter is between 75-150%
        # of the objective function value, so we come up with an estimate for 
        # tour length and use that.
        if G.number_of_edges()>0:
            lagrange = G.size(weight=weight)*G.number_of_nodes()/G.number_of_edges()
        else:
            lagrange = 2
    
    # calculate default missing_edge_weight if required
    if missing_edge_weight is None:
        # networkx method to calculate sum of all weights
        missing_edge_weight = G.size(weight=weight)

    # some input checking
    if N in (1, 2):
        msg = "graph must have at least 3 nodes or be empty"
        raise ValueError(msg)

    # Creating the QUBO
    Q = defaultdict(float)

    # Constraint that each row has exactly one 1
    for node in G:
        for pos_1 in range(N):
            Q[((node, pos_1), (node, pos_1))] -= lagrange
            for pos_2 in range(pos_1+1, N):
                Q[((node, pos_1), (node, pos_2))] += 2.0*lagrange

    # Constraint that each col has exactly one 1
    for pos in range(N):
        for node_1 in G:
            Q[((node_1, pos), (node_1, pos))] -= lagrange
            for node_2 in set(G)-{node_1}:
                # QUBO coefficient is 2*lagrange, but we are placing this value 
                # above *and* below the diagonal, so we put half in each position.
                Q[((node_1, pos), (node_2, pos))] += lagrange

    # Objective that minimizes distance
    for u, v in itertools.combinations(G.nodes, 2):
        for pos in range(N):
            nextpos = (pos + 1) % N

            # going from u -> v
            try:
                value = G[u][v][weight]
            except KeyError:
                value = missing_edge_weight

            Q[((u, pos), (v, nextpos))] += value

            # going from v -> u
            try:
                value = G[v][u][weight]
            except KeyError:
                value = missing_edge_weight

            Q[((v, pos), (u, nextpos))] += value

    return Q

traveling_salesman_qubo = traveling_salesperson_qubo

def is_hamiltonian_path(G, route):
    """Determines whether the given list forms a valid TSP route.
    A travelling salesperson route must visit each city exactly once.
    Parameters
    ----------
    G : NetworkX graph
        The graph on which to check the route.
    route : list
        List of nodes in the order that they are visited.
    Returns
    -------
    is_valid : bool
        True if route forms a valid travelling salesperson route.
    """
    return (set(route) == set(G))

# %%
# function to return total distance traveled by the salesperson in a cycle
def get_distance(route,data):
    
    total_dist = 0
    for idx, node in enumerate(route[:-1]):
        dist = data[route[idx+1]][route[idx]]
        total_dist += dist
    return_distance = data[route[0]][route[-1]]
    whole_distance = return_distance+total_dist
    
    return whole_distance

# %% [markdown]
# # Numbering nodes
#
# ###### Place --  Node Number
# Fort  --  0
#
# Churchgate --  1
#
# Khetwadi  --  2
#
# Malabar Hills  --  3
#
# Parel  --  4
#
# Dadar  --  5
#
# Wadala  --  6

# %% [markdown]
# ## Solution with Simulated Annealing

# %% [markdown]
# ### TSP with 5 nodes

# %%
import dimod
import matplotlib.pyplot as plt
import dwave_networkx as dnx
import networkx as nx
import pandas as pd
import itertools

# %matplotlib inline
from random import *
data5 = pd.read_csv('dataset_5.txt', sep ='\s+', header=None)

num_cities = data5.shape[0]
G = nx.from_pandas_adjacency(data5)
pos = nx.spring_layout(G, seed = randint(1,100))
nodes = G.nodes()
edges = G.edges()
weights = nx.get_edge_attributes(G,'weight')
plt.figure(figsize=(6,6))
plt.axis()
nx.draw_networkx(G, pos, with_labels=True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=weights, label_pos=0.25);

# %%
t0 = time.perf_counter()
route = dnx.traveling_salesperson(G, dimod.ExactSolver(), start=0)
t1 = time.perf_counter()
print('Route found with "Exact Solver":', route)
print('Total distance, with' + '\033[1m'+ ' "Exact Solver" '+'\033[0m'+
      'including return to initial node:', get_distance(route,data5), 'km')
print('Elapsed time for ' + '\033[1m'+ '"Exact Solver":' + '\033[0m', (t1-t0), 'sec')
print('')

t0 = time.perf_counter()
route2 = dnx.traveling_salesperson(G, dimod.SimulatedAnnealingSampler(), start=0)
t1 = time.perf_counter()
print('Route found with "Simulated Annealing Sampler":', route2)

print('Total distance, with' + '\033[1m'+ ' "Simulated Annealing Sampler" '+'\033[0m'+
      'including return to initial node:', get_distance(route2,data5), 'km')
print('Elapsed time for ' + '\033[1m'+ '"Simulated Annealing Sampler":' + '\033[0m', (t1-t0), 'sec')
# Out:
# Route found with "Exact Solver": [0, 1, 3, 4, 2]
# Total distance, with "Exact Solver" including return to initial node: 21.7 km
# Elapsed time for "Exact Solver": 62.78223150000001 sec
#
# Route found with "Simulated Annealing Sampler": [0, 1, 3, 4, 2]
# Total distance, with "Simulated Annealing Sampler" including return to initial node: 21.7 km
# Elapsed time for "Simulated Annealing Sampler": 2.9542292000000003 sec

# %% [markdown]
# #### Optimal route

# %%
sol_graph_base = [(route[idx], route[idx+1]) for idx in range(len(route)-1)]
sol_graph_base.append((route[len(route)-1], route[0]))
best_weights = {k: weights[k] if k in weights.keys() else weights[(k[1],k[0])] for k in sol_graph_base}
# Rebuild graph containing only route connections
G_best = nx.Graph(sol_graph_base)

route_labels = {x: f'step_{i}={best_weights[x]}' for i, x in enumerate(sol_graph_base)}

print('Optimal route')
plt.figure(figsize=(6,6))
plt.axis(); 
nx.draw_networkx(G_best, pos, font_color='w');
nx.draw_networkx_edge_labels(G_best, pos, edge_labels=route_labels, label_pos=0.25);
# Out:
# Optimal route

# %% [markdown]
# ## TSP with 7 nodes

# %%
import dimod
import matplotlib.pyplot as plt
import dwave_networkx as dnx
import networkx as nx
import pandas as pd
import itertools

# %matplotlib inline
from random import *
data7 = pd.read_csv('dataset_7.txt', sep ='\s+', header=None)

num_cities = data7.shape[0]
G = nx.from_pandas_adjacency(data7)
pos = nx.spring_layout(G, seed = randint(1,100))
nodes = G.nodes()
edges = G.edges()
weights = nx.get_edge_attributes(G,'weight')
print('Original graph')
plt.figure(figsize=(6,6))
plt.axis()
nx.draw_networkx(G, pos, with_labels=True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=weights, label_pos=0.25);
# Out:
# Original graph

# %%
print('\033[1m'+ '"Exact Solver" '+'\033[0m'+
      'does not work for nodes > 5')
print('')
print('Running with Simulated Annealing Sampler...')

# find default Langrange parameter for enforcing constraints
lagrange = None
weight = 'weight'
total_time = 0
best_distance = sum(weights.values())
best_route = [None]*len(G)
N = G.number_of_nodes()

if lagrange is None:
    # If no lagrange parameter provided, set to 'average' tour length.
    # Usually a good estimate for a lagrange parameter is between 75-150%
    # of the objective function value, so we come up with an estimate for 
    # tour length and use that.
    if G.number_of_edges()>0:
        lagrange = G.size(weight=weight)*G.number_of_nodes()/G.number_of_edges()
    else:
        lagrange = 2
print('Default Lagrange parameter:', lagrange)

# create list around default value for HPO
min_lagrange = int(0.8*lagrange)
max_lagrange = int(1.3*lagrange)
diff = max_lagrange - min_lagrange
gap = int(diff/9)

lagrange_list= list(np.arange(min_lagrange, max_lagrange, gap))
print('Lagrange parameter for HPO:', lagrange_list)

# run HPO to find route
t0 = time.perf_counter()
for lagrange in lagrange_list:
    print('Running quantum annealing for TSP with Lagrange parameter =', lagrange)
    
    route = traveling_salesperson(G, dimod.SimulatedAnnealingSampler(), lagrange=lagrange, start=0)
    
    print('Route found:', route)
    whole_distance = get_distance(route,data7)
    print('Distanced travelled on this route:', whole_distance)
    # update best values
    if whole_distance < best_distance:
        best_distance = whole_distance
        best_route = route

t1 = time.perf_counter()

avg_time = (t1-t0)/len(lagrange_list)

print('')
print('---FINAL SOLUTION---')
print('Best solution found with' + '\033[1m'+ ' "Simulated Annealing Sampler" '+'\033[0m', best_route)
print('Total distance (including return):', best_distance)
print('Elapsed time (average) for ' + '\033[1m'+ '"Simulated Annealing Sampler":'
      + '\033[0m', avg_time, 'sec')
# Out:
# "Exact Solver" does not work for nodes > 5
#
# Running with Simulated Annealing Sampler...
# Default Lagrange parameter: 51.2
# Lagrange parameter for HPO: [40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60, 62, 64]
# Running quantum annealing for TSP with Lagrange parameter = 40
# Route found: [0, 1, 2, 4, 6, 3, 5]
# Distanced travelled on this route: 48.300000000000004
# Running quantum annealing for TSP with Lagrange parameter = 42
# Route found: [0, 2, 5, 6, 1, 4, 3]
# Distanced travelled on this route: 51.10000000000001
# Running quantum annealing for TSP with Lagrange parameter = 44
# Route found: [0, 5, 3, 6, 4, 2, 1]
# Distanced travelled on this route: 48.3
# Running quantum annealing for TSP with Lagrange parameter = 46
# Route found: [0, 2, 5, 4, 6, 1, 3]
# Distanced travelled on this route: 44.7
# Running quantum annealing for TSP with Lagrange parameter = 48
# Route found: [0, 2, 1, 3, 5, 4, 6]
# Distanced travelled on this route: 41.1
# ...

# %% [markdown]
# ## Constructing the best possible route

# %% [markdown]
# #### Optimal route

# %%
node_labels = {list(nodes)[ii]: best_route[ii] for ii in range(N)}

sol_graph_base = [(best_route[idx], best_route[idx+1]) for idx in range(len(best_route)-1)]
sol_graph_base.append((best_route[len(route)-1], best_route[0]))
best_weights = {k: weights[k] if k in weights.keys() else weights[(k[1],k[0])] for k in sol_graph_base}
# Rebuild graph containing only route connections
G_best = nx.Graph(sol_graph_base)

route_labels = {x: f'step_{i}={best_weights[x]}' for i, x in enumerate(sol_graph_base)}

print('Optimal route')
plt.figure(figsize=(6,6))
plt.axis(); 
nx.draw_networkx(G_best, pos, font_color='w');
nx.draw_networkx_edge_labels(G_best, pos, edge_labels=route_labels, label_pos=0.25);
# Out:
# Optimal route

# %% [markdown]
# ### Calculating average time to run algorithm

# %%
#function for calculating average runtime 
def avg_time_func(data, sampler, run_times):
    G = nx.from_pandas_adjacency(data)
    weights = nx.get_edge_attributes(G,'weight')
    t0 = time.perf_counter()
    for i in range(run_times):
        route = dnx.traveling_salesperson(G, sampler, start=0)
    t1 = time.perf_counter()
    avg_time = (t1-t0)/(run_times)
    
    return avg_time

# %%
data = pd.read_csv('dataset_3.txt' , sep ='\s+', header=None)
time_ES_3 = avg_time_func(data, dimod.ExactSolver(), 10)
print('Average runtime for 3 nodes with Exact Solver: ', time_ES_3)
print('')
##---------------------
data = pd.read_csv('dataset_4.txt' , sep ='\s+', header=None)
time_ES_4 = avg_time_func(data, dimod.ExactSolver(), 10)
print('Avergae runtime for 4 nodes with Exact Solver: ', time_ES_4)
print('')
##---------------------
data = pd.read_csv('dataset_5.txt' , sep ='\s+', header=None)
time_ES_5 = avg_time_func(data, dimod.ExactSolver(), 10)
print('Avergae runtime for 5 nodes with Exact Solver: ', time_ES_5)
# Out:
# Average runtime for 3 nodes with Exact Solver:  0.0011385700000005271
#
# Avergae runtime for 4 nodes with Exact Solver:  0.09430608000000121
#
# Avergae runtime for 5 nodes with Exact Solver:  61.86631562

# %%
data = pd.read_csv('dataset_3.txt' , sep ='\s+', header=None)
time_SAS_3 = avg_time_func(data, dimod.SimulatedAnnealingSampler(), 25)
print('Avergae runtime for 3 nodes with Exact Solver: ', time_SAS_3)
print('')
##---------------------
data = pd.read_csv('dataset_4.txt' , sep ='\s+', header=None)
time_SAS_4 = avg_time_func(data, dimod.SimulatedAnnealingSampler(), 25)
print('Avergae runtime for 4 nodes with Exact Solver: ', time_SAS_4)
print('')
##---------------------
data = pd.read_csv('dataset_5.txt' , sep ='\s+', header=None)
time_SAS_5 = avg_time_func(data, dimod.SimulatedAnnealingSampler(), 25)
print('Avergae runtime for 5 nodes with Exact Solver: ', time_SAS_5)
print('')
##---------------------
data = pd.read_csv('dataset_6.txt' , sep ='\s+', header=None)
time_SAS_6 = avg_time_func(data, dimod.SimulatedAnnealingSampler(), 25)
print('Avergae runtime for 6 nodes with Exact Solver: ', time_SAS_6)
print('')
##---------------------
data = pd.read_csv('dataset_7.txt' , sep ='\s+', header=None)
time_SAS_7 = avg_time_func(data, dimod.SimulatedAnnealingSampler(), 25)
print('Avergae runtime for 7 nodes with Exact Solver: ', time_SAS_7)
# Out:
# Avergae runtime for 3 nodes with Exact Solver:  0.6089943760000005
#
# Avergae runtime for 4 nodes with Exact Solver:  1.4473222239999997
#
# Avergae runtime for 5 nodes with Exact Solver:  2.9989208319999987
#
# Avergae runtime for 6 nodes with Exact Solver:  5.286444267999996
#
# Avergae runtime for 7 nodes with Exact Solver:  8.365121611999994

# %% [markdown]
# ###### Make the following plots by noting the values from the above results

# %%
nodes_ES = [3,4,5]
time_ES = (time_ES_3,time_ES_4,time_ES_5)
nodes_SAS = [3,4,5,6,7]
time_SAS = (time_SAS_3,time_SAS_4,time_SAS_5,time_SAS_6,time_SAS_7)

# %%
fig, ax1 = plt.subplots()
plt.bar(nodes_ES,time_ES,color = 'b',
        width = 0.25, edgecolor = 'black')
plt.xlabel('Number of nodes')
plt.ylabel('Average runtime (sec)')
plt.title("Average runtime for Exact Solver");
left, bottom, width, height = [0.26, 0.5, 0.35, 0.35]
ax2 = fig.add_axes([left, bottom, width, height])
plt.bar([3,4],[time_ES_3,time_ES_4],color = 'b', width = 0.25, edgecolor = 'black');

# %%
plt.bar(nodes_SAS,time_SAS,color = 'g', width = 0.25, edgecolor = 'black')
plt.xlabel('Number of nodes')
plt.ylabel('Average runtime (sec)')
plt.title("Average runtime for Simulated Anneling Sampler");

# %% [markdown]
# ## Solution on D-Wave Quantum Annealer

# %% [markdown]
# ###### We ran into an issue while running the code on either Amazon D-wave or Amazon Braket !!!
# The codes run fine on simulators. With one of two lines of correct instructions in the following code, one can run them on either platforms. Suggestions and feedbacks are always welcome.

# %%
"""
    Using Amazon Braket

"""
import boto3
from braket.aws import AwsDevice
from braket.ocean_plugin import BraketSampler, BraketDWaveSampler

##   Put Amazon-Braket account details here!!

sampler = BraketDWaveSampler(device_arn='arn:aws:braket:::device/qpu/d-wave/DW_2000Q_6')
sampler = EmbeddingComposite(sampler)
num_shots = 1000
route = traveling_salesperson(G, sampler, lagrange=lagrange,
                              start=0, num_reads=num_shots, answer_mode="histogram")
print('Route found with D-Wave:', route)
total_dist = 0
for idx, node in enumerate(route[:-1]):
    dist = data[route[idx+1]][route[idx]]
    total_dist += dist
    
return_distance = data[route[0]][route[-1]]
print('Total distance from D-Wave quantum annealer, including return to initial node:',
      return_distance+total_dist)

# %%
"""
    Using D-wave
    
"""
import boto3
from braket.aws import AwsDevice
from braket.ocean_plugin import BraketSampler, BraketDWaveSampler
import sys
from dwave.embedding.chain_strength import scaled
from dwave.system.composites import EmbeddingComposite
from dwave.system.samplers import DWaveSampler
import dwave.inspector


#qpu = DWaveSampler(solver={'topology__type': 'pegasus'})
sampler = EmbeddingComposite(DWaveSampler()) # QPU sampler to run in production

num_shots = 1000
route = traveling_salesperson(G, sampler, lagrange=lagrange,
                              start=0, num_reads=num_shots, answer_mode="histogram")
print('Route found with D-Wave:', route)
total_dist = 0
for idx, node in enumerate(route[:-1]):
    dist = data[route[idx+1]][route[idx]]
    total_dist += dist
    
return_distance = data[route[0]][route[-1]]
print('Total distance from D-Wave quantum annealer, including return to initial node:',
      return_distance+total_dist)
